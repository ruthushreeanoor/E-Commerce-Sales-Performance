# %% [markdown]
# # 🛒 E-Commerce Sales Performance
#
# **Company:** SwiftCart Retail
# **Role:** Sales Operations Analyst
#
# ## 🏢 Scenario
#
# SwiftCart Retail is looking to optimize its inventory for the next quarter. You have been assigned to identify which product categories are **“cash cows”** and which ones are underperforming based on sales performance and customer feedback.
#
# ---
#
# ## 🎯 Your Tasks
#
# ### 1️⃣ Calculate Revenue
#
# * Create a new column called **`Total_Sales`** using the formula:
#
# ```
# Total_Sales = Price × Quantity
# ```
#
# * This will represent the total revenue generated per product.
#
# ---
#
# ### 2️⃣ Identify Top Performers
#
# * Group the data by **Category**.
# * Calculate total sales per category.
# * Determine which category has the **highest total sales**.
#
# ---
#
# ### 3️⃣ Customer Satisfaction Analysis
#
# * Compute the **average product rating** across all products.
# * Briefly interpret what this means for overall customer satisfaction.
#
# ---
#
# ### 4️⃣ Premium Product Filtering
#
# * Filter and list all products where:
#
# ```
# Rating > 4
# ```
#
# * These represent high-performing, highly rated products.
#
# ---
#
# ### 5️⃣ Visualization – Sales Performance
#
# * Create a **Bar Chart** showing:
#
# ```
# Category vs. Total Sales
# ```
#
# * Include:
#
#   * Chart title
#   * Axis labels
#   * Clear formatting for readability
#
# ---
#
# ### 6️⃣ Pricing Analysis
#
# * Create a **Histogram** of product prices.
# * Analyze:
#
#   * Most common price ranges
#   * Price distribution trends
#
# ---
#
# ## 📌 Expected Outcome
#
# By completing this analysis, you should be able to:
#
# * Identify high-revenue product categories
# * Understand customer satisfaction trends
# * Recognize premium-performing products
# * Analyze pricing distribution
# * Provide data-driven recommendations for inventory optimization
#
# ---

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("/content/ecommerce_sales_dataset.csv")
data
# Out:
#     Order_ID Product_Category  Price  Quantity  Customer_Rating
# 0       1001            Books   1894         4              3.8
# 1       1002      Electronics   2210         1              4.6
# 2       1003         Clothing    897         2              4.2
# 3       1004         Clothing   3890         1              2.8
# 4       1005      Electronics   3529         3              3.6
# 5       1006             Home   2228         2              4.7
# 6       1007             Home    697         3              4.8
# 7       1008             Home   2349         4              4.8
# 8       1009             Home   3522         4              2.5
# 9       1010             Home   3080         5              4.4
# 10      1011             Home   1981         5              3.0
# 11      1012      Electronics   1679         1              4.8
# 12      1013             Home   2130         2              4.2
# 13      1014             Home    733         2              2.9
# 14      1015         Clothing   2742         2              2.6
# 15      1016             Home   2703         4              5.0
# 16      1017      Electronics    331         5              3.1
# 17      1018      Electronics   3863         5              2.9
# 18      1019      Electronics   3464         1              3.4
# 19      1020         Clothing   2759         5              5.0

# %%
data.head()
# Out:
#    Order_ID Product_Category  Price  Quantity  Customer_Rating
# 0      1001            Books   1894         4              3.8
# 1      1002      Electronics   2210         1              4.6
# 2      1003         Clothing    897         2              4.2
# 3      1004         Clothing   3890         1              2.8
# 4      1005      Electronics   3529         3              3.6

# %%
data.tail()
# Out:
#     Order_ID Product_Category  Price  Quantity  Customer_Rating
# 15      1016             Home   2703         4              5.0
# 16      1017      Electronics    331         5              3.1
# 17      1018      Electronics   3863         5              2.9
# 18      1019      Electronics   3464         1              3.4
# 19      1020         Clothing   2759         5              5.0

# %%
data.info() #Valuable information about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          20 non-null     int64
#  1   Product_Category  20 non-null     object
#  2   Price             20 non-null     int64
#  3   Quantity          20 non-null     int64
#  4   Customer_Rating   20 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 932.0+ bytes

# %%
# Statistics of data
data.describe()
# Out:
#          Order_ID        Price   Quantity  Customer_Rating
# count    20.00000    20.000000  20.000000        20.000000
# mean   1010.50000  2334.050000   3.050000         3.855000
# std       5.91608  1077.293073   1.538112         0.889397
# min    1001.00000   331.000000   1.000000         2.500000
# 25%    1005.75000  1840.250000   2.000000         2.975000
# 50%    1010.50000  2288.500000   3.000000         4.000000
# 75%    1015.25000  3176.000000   4.250000         4.725000
# max    1020.00000  3890.000000   5.000000         5.000000

# %%
# How many are the total orders today
len(data)
# Out:
# 20

# %%
# How many product categories
data["Product_Category"].unique()
data["Product_Category"]
# Out:
# 0           Books
# 1     Electronics
# 2        Clothing
# 3        Clothing
# 4     Electronics
# 5            Home
# 6            Home
# 7            Home
# 8            Home
# 9            Home
# 10           Home
# 11    Electronics
# 12           Home
# 13           Home
# 14       Clothing
# 15           Home
# 16    Electronics
# 17    Electronics
# 18    Electronics
# 19       Clothing
# Name: Product_Category, dtype: object

# %%
data["Product_Category"].unique()
# Out:
# array(['Books', 'Electronics', 'Clothing', 'Home'], dtype=object)

# %%
#Calculate Average price of today's sale

data["Price"].mean()#Customer Segmentation,Customer Spending Patterns
# Out:
# np.float64(2334.05)

# %%
data["Price"].max()
# Out:
# 3890

# %%
data["Price"].min()
# Out:
# 331

# %%
len(data)
# Out:
# 20

# %% [markdown]
# # Data filtering

# %%
data["Price"]
# Out:
# 0     1894
# 1     2210
# 2      897
# 3     3890
# 4     3529
# 5     2228
# 6      697
# 7     2349
# 8     3522
# 9     3080
# 10    1981
# 11    1679
# 12    2130
# 13     733
# 14    2742
# 15    2703
# 16     331
# 17    3863
# 18    3464
# 19    2759
# Name: Price, dtype: int64

# %%
data["Price"]>3000
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True
# 5     False
# 6     False
# 7     False
# 8      True
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17     True
# 18     True
# 19    False
# Name: Price, dtype: bool

# %%
data[data["Price"]>3000]
# Out:
#     Order_ID Product_Category  Price  Quantity  Customer_Rating
# 3       1004         Clothing   3890         1              2.8
# 4       1005      Electronics   3529         3              3.6
# 8       1009             Home   3522         4              2.5
# 9       1010             Home   3080         5              4.4
# 17      1018      Electronics   3863         5              2.9
# 18      1019      Electronics   3464         1              3.4

# %%
data[data["Customer_Rating"]>3.5]
# Out:
#     Order_ID Product_Category  Price  Quantity  Customer_Rating
# 0       1001            Books   1894         4              3.8
# 1       1002      Electronics   2210         1              4.6
# 2       1003         Clothing    897         2              4.2
# 4       1005      Electronics   3529         3              3.6
# 5       1006             Home   2228         2              4.7
# 6       1007             Home    697         3              4.8
# 7       1008             Home   2349         4              4.8
# 9       1010             Home   3080         5              4.4
# 11      1012      Electronics   1679         1              4.8
# 12      1013             Home   2130         2              4.2
# 15      1016             Home   2703         4              5.0
# 19      1020         Clothing   2759         5              5.0

# %%
(data[data["Customer_Rating"]>3.5]).count()
# Out:
# Order_ID            12
# Product_Category    12
# Price               12
# Quantity            12
# Customer_Rating     12
# dtype: int64

# %%
data[data["Product_Category"]=="Electronics"]
# Out:
#     Order_ID Product_Category  Price  Quantity  Customer_Rating
# 1       1002      Electronics   2210         1              4.6
# 4       1005      Electronics   3529         3              3.6
# 11      1012      Electronics   1679         1              4.8
# 16      1017      Electronics    331         5              3.1
# 17      1018      Electronics   3863         5              2.9
# 18      1019      Electronics   3464         1              3.4

# %%
len(data[data["Product_Category"]=="Clothing"])
# Out:
# 4

# %%
data[(data["Product_Category"]=="Clothing") & (data["Price"]>3000)]
# Out:
#    Order_ID Product_Category  Price  Quantity  Customer_Rating
# 3      1004         Clothing   3890         1              2.8

# %%
data[(data["Product_Category"]=="Home") & (data["Customer_Rating"]>3.5)]
# Out:
#     Order_ID Product_Category  Price  Quantity  Customer_Rating
# 5       1006             Home   2228         2              4.7
# 6       1007             Home    697         3              4.8
# 7       1008             Home   2349         4              4.8
# 9       1010             Home   3080         5              4.4
# 12      1013             Home   2130         2              4.2
# 15      1016             Home   2703         4              5.0

# %% [markdown]
# # Data Sorting

# %%
data.sort_values("Price")
# Out:
#     Order_ID Product_Category  Price  Quantity  Customer_Rating
# 16      1017      Electronics    331         5              3.1
# 6       1007             Home    697         3              4.8
# 13      1014             Home    733         2              2.9
# 2       1003         Clothing    897         2              4.2
# 11      1012      Electronics   1679         1              4.8
# 0       1001            Books   1894         4              3.8
# 10      1011             Home   1981         5              3.0
# 12      1013             Home   2130         2              4.2
# 1       1002      Electronics   2210         1              4.6
# 5       1006             Home   2228         2              4.7
# 7       1008             Home   2349         4              4.8
# 15      1016             Home   2703         4              5.0
# 14      1015         Clothing   2742         2              2.6
# 19      1020         Clothing   2759         5              5.0
# 9       1010             Home   3080         5              4.4
# 18      1019      Electronics   3464         1              3.4
# 8       1009             Home   3522         4              2.5
# 4       1005      Electronics   3529         3              3.6
# 17      1018      Electronics   3863         5              2.9
# 3       1004         Clothing   3890         1              2.8

# %%
data.sort_values("Price",ascending=False) #top_sales products,bestsellers
# Out:
#     Order_ID Product_Category  Price  Quantity  Customer_Rating
# 3       1004         Clothing   3890         1              2.8
# 17      1018      Electronics   3863         5              2.9
# 4       1005      Electronics   3529         3              3.6
# 8       1009             Home   3522         4              2.5
# 18      1019      Electronics   3464         1              3.4
# 9       1010             Home   3080         5              4.4
# 19      1020         Clothing   2759         5              5.0
# 14      1015         Clothing   2742         2              2.6
# 15      1016             Home   2703         4              5.0
# 7       1008             Home   2349         4              4.8
# 5       1006             Home   2228         2              4.7
# 1       1002      Electronics   2210         1              4.6
# 12      1013             Home   2130         2              4.2
# 10      1011             Home   1981         5              3.0
# 0       1001            Books   1894         4              3.8
# 11      1012      Electronics   1679         1              4.8
# 2       1003         Clothing    897         2              4.2
# 13      1014             Home    733         2              2.9
# 6       1007             Home    697         3              4.8
# 16      1017      Electronics    331         5              3.1

# %%
data.sort_values("Customer_Rating",ascending=False)
# Out:
#     Order_ID Product_Category  Price  Quantity  Customer_Rating
# 15      1016             Home   2703         4              5.0
# 19      1020         Clothing   2759         5              5.0
# 6       1007             Home    697         3              4.8
# 7       1008             Home   2349         4              4.8
# 11      1012      Electronics   1679         1              4.8
# 5       1006             Home   2228         2              4.7
# 1       1002      Electronics   2210         1              4.6
# 9       1010             Home   3080         5              4.4
# 2       1003         Clothing    897         2              4.2
# 12      1013             Home   2130         2              4.2
# 0       1001            Books   1894         4              3.8
# 4       1005      Electronics   3529         3              3.6
# 18      1019      Electronics   3464         1              3.4
# 16      1017      Electronics    331         5              3.1
# 10      1011             Home   1981         5              3.0
# 17      1018      Electronics   3863         5              2.9
# 13      1014             Home    733         2              2.9
# 3       1004         Clothing   3890         1              2.8
# 14      1015         Clothing   2742         2              2.6
# 8       1009             Home   3522         4              2.5

# %% [markdown]
# # Creating New Columns

# %%
data[["Quantity","Price"]]
# Out:
#     Quantity  Price
# 0          4   1894
# 1          1   2210
# 2          2    897
# 3          1   3890
# 4          3   3529
# 5          2   2228
# 6          3    697
# 7          4   2349
# 8          4   3522
# 9          5   3080
# 10         5   1981
# 11         1   1679
# 12         2   2130
# 13         2    733
# 14         2   2742
# 15         4   2703
# 16         5    331
# 17         5   3863
# 18         1   3464
# 19         5   2759

# %%
data["Total"]=(data["Price"]*data["Quantity"])

# %%
data
# Out:
#     Order_ID Product_Category  Price  Quantity  Customer_Rating  Total
# 0       1001            Books   1894         4              3.8   7576
# 1       1002      Electronics   2210         1              4.6   2210
# 2       1003         Clothing    897         2              4.2   1794
# 3       1004         Clothing   3890         1              2.8   3890
# 4       1005      Electronics   3529         3              3.6  10587
# 5       1006             Home   2228         2              4.7   4456
# 6       1007             Home    697         3              4.8   2091
# 7       1008             Home   2349         4              4.8   9396
# 8       1009             Home   3522         4              2.5  14088
# 9       1010             Home   3080         5              4.4  15400
# 10      1011             Home   1981         5              3.0   9905
# 11      1012      Electronics   1679         1              4.8   1679
# 12      1013             Home   2130         2              4.2   4260
# 13      1014             Home    733         2              2.9   1466
# 14      1015         Clothing   2742         2              2.6   5484
# 15      1016             Home   2703         4              5.0  10812
# 16      1017      Electronics    331         5              3.1   1655
# 17      1018      Electronics   3863         5              2.9  19315
# 18      1019      Electronics   3464         1              3.4   3464
# 19      1020         Clothing   2759         5              5.0  13795

# %%
data["GST"]=(data["Price"]*0.18)

# %%
data
# Out:
#     Order_ID Product_Category  Price  Quantity  Customer_Rating  Total     GST
# 0       1001            Books   1894         4              3.8   7576  340.92
# 1       1002      Electronics   2210         1              4.6   2210  397.80
# 2       1003         Clothing    897         2              4.2   1794  161.46
# 3       1004         Clothing   3890         1              2.8   3890  700.20
# 4       1005      Electronics   3529         3              3.6  10587  635.22
# 5       1006             Home   2228         2              4.7   4456  401.04
# 6       1007             Home    697         3              4.8   2091  125.46
# 7       1008             Home   2349         4              4.8   9396  422.82
# 8       1009             Home   3522         4              2.5  14088  633.96
# 9       1010             Home   3080         5              4.4  15400  554.40
# 10      1011             Home   1981         5              3.0   9905  356.58
# 11      1012      Electronics   1679         1              4.8   1679  302.22
# 12      1013             Home   2130         2              4.2   4260  383.40
# 13      1014             Home    733         2              2.9   1466  131.94
# 14      1015         Clothing   2742         2              2.6   5484  493.56
# 15      1016             Home   2703         4              5.0  10812  486.54
# 16      1017      Electronics    331         5              3.1   1655   59.58
# 17      1018      Electronics   3863         5              2.9  19315  695.34
# 18      1019      Electronics   3464         1              3.4   3464  623.52
# 19      1020         Clothing   2759         5              5.0  13795  496.62

# %%
data["Discount"] = np.where(data["Product_Category"] == "Electronics", data["Price"] * 0.15, 0)
display(data)
# Out:
#     Order_ID Product_Category  Price  Quantity  Customer_Rating  Total  \
# 0       1001            Books   1894         4              3.8   7576
# 1       1002      Electronics   2210         1              4.6   2210
# 2       1003         Clothing    897         2              4.2   1794
# 3       1004         Clothing   3890         1              2.8   3890
# 4       1005      Electronics   3529         3              3.6  10587
# 5       1006             Home   2228         2              4.7   4456
# 6       1007             Home    697         3              4.8   2091
# 7       1008             Home   2349         4              4.8   9396
# 8       1009             Home   3522         4              2.5  14088
# 9       1010             Home   3080         5              4.4  15400
# 10      1011             Home   1981         5              3.0   9905
# 11      1012      Electronics   1679         1              4.8   1679
# 12      1013             Home   2130         2              4.2   4260
# 13      1014             Home    733         2              2.9   1466
# 14      1015         Clothing   2742         2              2.6   5484
# 15      1016             Home   2703         4              5.0  10812
# 16      1017      Electronics    331         5              3.1   1655
# 17      1018      Electronics   3863         5              2.9  19315
# 18      1019      Electronics   3464         1              3.4   3464
# 19      1020         Clothing   2759         5              5.0  13795
#
#        GST  Discount
# 0   340.92      0.00
# 1   397.80    331.50
# 2   161.46      0.00
# 3   700.20      0.00
# 4   635.22    529.35
# 5   401.04      0.00
# 6   125.46      0.00
# 7   422.82      0.00
# 8   633.96      0.00
# 9   554.40      0.00
# 10  356.58      0.00
# 11  302.22    251.85
# 12  383.40      0.00
# 13  131.94      0.00
# 14  493.56      0.00
# 15  486.54      0.00
# 16   59.58     49.65
# 17  695.34    579.45
# 18  623.52    519.60
# 19  496.62      0.00
